# %%
from rdflib import Graph
g = Graph()
g.parse("http://bigasterisk.com/foaf.rdf")

print(g.serialize())
# Out:
# @prefix : <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix admin: <http://webns.net/mvcb/> .
# @prefix cert: <http://www.w3.org/ns/auth/cert#> .
# @prefix doap: <http://usefulinc.com/ns/doap#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix redfoot: <http://redfoot.net/2005/session#> .
# @prefix rsa: <http://www.w3.org/ns/auth/rsa#> .
#
# <https://bigasterisk.com/foaf.rdf> a foaf:PersonalProfileDocument ;
#     admin:errorReportsTo <mailto:leigh@ldodds.com> ;
#     admin:generatorAgent <http://www.ldodds.com/foaf/foaf-a-matic> ;
#     foaf:maker <http://bigasterisk.com/foaf.rdf#drewp> ;
#     foaf:primaryTopic <http://bigasterisk.com/foaf.rdf#drewp> .
#
# <http://bblfish.net/people/henry/card#me> a foaf:Person ;
#     rdfs:seeAlso <http://bblfish.net/people/henry/card> ;
#     foaf:name "Henry Story" .
#
# ...

# %% [markdown]
# ![picture 2](_resources/916840a392b04565a488ae7ab71388d81eccedc3de1d29e895681455fae90aca.png)

# %% [markdown]
# 29 bzw mit leeren Knoten 35 sind potentielle Subjekte
# Wirklich genutzt werden allerdings nur 6 bzw. mit leeren Knoten 12
#
# Es gibt 20 Literale

# %%
query = """
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
SELECT ?xname ?yname

WHERE
{
    # ?x foaf:knows ?y.
    # ?x foaf:name ?xname.
    # ?y foaf:name ?yname.
}
"""

qres = g.query(query)

for (x, y) in qres:
    print(f'{x} knows {y}')


query = """
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
SELECT ?project

WHERE
{
    # ?x foaf:name "Drew Perttula".
    # ?x foaf:currentProject ?project.
}
"""

qres = g.query(query)

for x in qres:
    print(f'Drew Perttula works on {x[0]}')


subjects = set()

for s, p, o in g:
    subjects.add(s)


query = """
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
SELECT ?project

WHERE
{
    # ?x foaf:currentProject ?project.
    # ?project ?y ?z.
}
"""

qres = g.query(query)

for x in qres:
    print(x)
# Out:
# Drew Perttula knows David McClosky
# Drew Perttula knows Kelsi Perttula
# Drew Perttula knows Nathan Wilson
# Drew Perttula knows Henry Story
# Drew Perttula works on http://gasuse.bigasterisk.com/
# Drew Perttula works on http://fantasyfamegame.com/
# (rdflib.term.URIRef('http://gasuse.bigasterisk.com/'),)
# (rdflib.term.URIRef('http://fantasyfamegame.com/'),)
